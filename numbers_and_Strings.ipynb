# %%
## is used to specify the comments
##-------------------------------------------------------16/06/2025------------------------------------------------------------------

# %%
9+9
# Out:
# 18

# %%
9-9
# Out:
# 0

# %%
9*9
# Out:
# 81

# %%
9/9
# Out:
# 1.0

# %%
9**9
# Out:
# 387420489

# %%
9//9
# Out:
# 1

# %%
2.14
# Out:
# 2.14

# %%
9**1 #** performs square
# Out:
# 9

# %%
9//2 #//performs the floor division, and ignores the fractional part, shoows only integer part
# Out:
# 4

# %%
math.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-20-929699079.py in <cell line: 0>()
# ----> 1 math.pi
#
# NameError: name 'math' is not defined

# %%
import math #importing the math module which provides math funtions
math.pi
# Out:
# 3.141592653589793

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-3305111549.py in <cell line: 0>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
'hello world'
# Out:
# 'hello world'

# %%
"hello world"
# Out:
# 'hello world'

# %%
'''hello world'''
# Out:
# 'hello world'

# %%
'hello
world'
# Out:
#   File "/tmp/ipython-input-12-3924038793.py", line 1
#     'hello
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"hello
world"
# Out:
#   File "/tmp/ipython-input-13-4029956654.py", line 1
#     "hello
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''hello
# Out:
#   File "/tmp/ipython-input-14-2894116554.py", line 1
#     '''hello
#     ^
# SyntaxError: incomplete input

# %%
'''hello
world''' #only triple quote will work for multiline
# Out:
# 'hello\nworld'

# %%
_ #stores the last result
# Out:
# 'hello\nworld'

# %%
""" hello
world """ #in python, both single quote and double quote act same
# Out:
# ' hello \nworld '

# %%
"It's a rainy day" #no need of escaping the '(single quote)
# Out:
# "It's a rainy day"

# %%
'It's a rainy day'
# Out:
#   File "/tmp/ipython-input-24-231231099.py", line 1
#     'It's a rainy day'
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'it"s a rainy day' #here there is no need of escaping the "(double quote). in this type of cases, we can use double quote for showing single quote and
  # can use single quote for showing double quote
# Out:
# 'it"s a rainy day'

# %%
# In python, there is no multi-line comment option like in others (/*...*/)
# hash can be used for all the comment lines individually

# %%
#------------------------------------------------------------17/06/2025---------------------------------------------------------------------------------

# %%
v=5

# %%
v
# Out:
# 5

# %%
_
# Out:
# 5

# %%
_+5
# Out:
# 10

# %%
id(v) #memory location address
# Out:
# 10757864

# %%
1v=10   #Variable name does not starts with number, but can end with number
# Out:
#   File "/tmp/ipython-input-31-767183069.py", line 1
#     1v=10
#     ^
# SyntaxError: invalid decimal literal

# %%
v1=10

# %%
#case sensitive variable names-means lower case and upper case are different
a=1
A=10
a
# Out:
# 1

# %%
A
# Out:
# 10

# %%
# special characters are not allowed
@=5
# Out:
#   File "/tmp/ipython-input-39-3203086011.py", line 2
#     @=5
#     ^
# SyntaxError: invalid syntax

# %%
# keywords are not allowed
if=5
# Out:
#   File "/tmp/ipython-input-40-635789648.py", line 2
#     if=5
#       ^
# SyntaxError: invalid syntax

# %%
# only _ underscore is allowed and it can be in the begining also for variable names
_v=10

# %%
_v
# Out:
# 10

# %%
import keyword
keyword.keywords
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-43-2102949108.py in <cell line: 0>()
#       1 import keyword
# ----> 2 keyword.keywords
#
# AttributeError: module 'keyword' has no attribute 'keywords'

# %%
keyword.kwlist #shows the keywords list
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist) # finding the total number of keywords or reserved words in python
# Out:
# 35

# %%
v=5 #integer
v
# Out:
# 5

# %%
type(v)
# Out:
# int

# %%
v1=5.512 #float
v1
# Out:
# 5.5

# %%
type(v1) #need to check with sir why is the type not showing as float
# Out:
# int

# %%
v='nit' #string
v
# Out:
# 'nit'

# %%
type(v)
# Out:
# str

# %%
v="nit" #string
v
# Out:
# 'nit'

# %%
v=True #boolean value. True/False is only allowed, not true/false - case sensitive
v
# Out:
# True

# %%
type(v)
# Out:
# bool

# %%
v=1+2j #complex data type
v
# Out:
# (1+2j)

# %%
type(v)
# Out:
# complex
